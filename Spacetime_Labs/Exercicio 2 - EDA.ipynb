# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import skewtest
from scipy.stats import kurtosistest
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD, Adam

print ("Libraries sucessfully loaded")
# Out:
# Libraries sucessfully loaded

# %%
# loading dataset_case file, hosted in Github repository for easy compatibility of this notebook when shared 
filename_exp = "https://raw.githubusercontent.com/tiagottmoraes/STL_test/main/Datasets/Dataset_case_CLEAN.csv"

# %%
df=pd.read_csv(filename_exp)

# %%
df=df.drop(['Unnamed: 0'], axis = 1)

# %% [markdown]
# # EDA

# %% [markdown]
# ## The following EDA was carried out using 3 distinct analysis:
# - A. Correlation Test
# - B. Skewness Test
# - C. Variance Test

# %% [markdown]
# ### A. Correlation Test

# %%
df.corr()['tch_bloco'].sort_values(ascending=False)
# Out:
# tch_bloco        1.000000
# NDVI_1Q          0.543077
# NDVI_2Q          0.294158
# NDVI_4Q          0.247179
# safra            0.030871
# id_bloco        -0.000252
# NDVI_3Q         -0.022711
# area_bloco      -0.053810
# quant_talhoes   -0.080458
# mes_colheita    -0.318487
# Name: tch_bloco, dtype: float64

# %%
plt.figure(figsize = (15,9))
mask=np.triu(df.corr())
sns.heatmap(df.corr(), mask=mask, annot=True, cmap='OrRd')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### B. Uniformity Test (distribuition uniformity) - Skewness and Kurtosis

# %%
df.hist(bins=20, color='orange', figsize=(16,16))
plt.tight_layout()

# %%
print (stats.skewtest(df['NDVI_1Q'],axis=0))
print (stats.kurtosistest(df['NDVI_1Q'], axis=0, nan_policy='propagate'))
# Out:
# SkewtestResult(statistic=-1.731159778994065, pvalue=0.08342327081131114)
# KurtosistestResult(statistic=-11.219450510875902, pvalue=3.2729775595816995e-29)

# %%
print (stats.skewtest(df['NDVI_2Q'],axis=0))
print (stats.kurtosistest(df['NDVI_2Q'], axis=0, nan_policy='propagate'))
# Out:
# SkewtestResult(statistic=-7.966341913475098, pvalue=1.6344033723171155e-15)
# KurtosistestResult(statistic=1.969775400987119, pvalue=0.04886411700454631)

# %%
print (stats.skewtest(df['NDVI_3Q'],axis=0))
print (stats.kurtosistest(df['NDVI_3Q'], axis=0, nan_policy='propagate'))
# Out:
# SkewtestResult(statistic=-7.870134483420954, pvalue=3.542602279976638e-15)
# KurtosistestResult(statistic=-4.213762456506823, pvalue=2.5115143052854924e-05)

# %%
print (stats.skewtest(df['NDVI_4Q'],axis=0))
print (stats.kurtosistest(df['NDVI_4Q'], axis=0, nan_policy='propagate'))
# Out:
# SkewtestResult(statistic=11.043329970495286, pvalue=2.3611720655502055e-28)
# KurtosistestResult(statistic=0.0685208370255149, pvalue=0.9453710335083129)

# %% [markdown]
# ### C. Variance Test

# %%
sns.jointplot(data=df, x="area_bloco", y="tch_bloco", kind="reg")
stats.pearsonr(df['area_bloco'],df['tch_bloco'])
print ('Pearson, P-Valor = ', stats.pearsonr(df['area_bloco'],df['tch_bloco']))
# Out:
# Pearson, P-Valor =  (-0.053809582585254485, 0.002452080286892261)

# %%
width = 12
height = 10
plt.figure(figsize=(width,height))
sns.residplot(df['area_bloco'], df['tch_bloco'])
plt.show()
# Out:
# C:\Users\tiago\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data=df, x="NDVI_1Q", y="tch_bloco", kind="reg")
stats.pearsonr(df['NDVI_1Q'],df['tch_bloco'])
print ('Pearson, P-Valor = ', stats.pearsonr(df['NDVI_1Q'],df['tch_bloco']))
# Out:
# Pearson, P-Valor =  (0.5430771752232849, 1.742998272394298e-242)

# %%
width = 12
height = 10
plt.figure(figsize=(width,height))
sns.residplot(df['NDVI_1Q'], df['tch_bloco'])
plt.show()
# Out:
# C:\Users\tiago\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data=df, x="NDVI_2Q", y="tch_bloco", kind="reg")
stats.pearsonr(df['NDVI_2Q'],df['tch_bloco'])
print ('Pearson, P-Valor = ', stats.pearsonr(df['NDVI_2Q'],df['tch_bloco']))
# Out:
# Pearson, P-Valor =  (0.29415756608965443, 3.0297943031280924e-64)

# %%
width = 12
height = 10
plt.figure(figsize=(width,height))
sns.residplot(df['NDVI_2Q'], df['tch_bloco'])
plt.show()
# Out:
# C:\Users\tiago\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data=df, x="NDVI_3Q", y="tch_bloco", kind="reg")
stats.pearsonr(df['NDVI_3Q'],df['tch_bloco'])
print ('Pearson, P-Valor = ', stats.pearsonr(df['NDVI_3Q'],df['tch_bloco']))
# Out:
# Pearson, P-Valor =  (-0.02271096335684071, 0.20133942172764993)

# %%
width = 12
height = 10
plt.figure(figsize=(width,height))
sns.residplot(df['NDVI_3Q'], df['tch_bloco'])
plt.show()
# Out:
# C:\Users\tiago\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data=df, x="NDVI_4Q", y="tch_bloco", kind="reg")
stats.pearsonr(df['NDVI_4Q'],df['tch_bloco'])
print ('Pearson, P-Valor = ', stats.pearsonr(df['NDVI_4Q'],df['tch_bloco']))
# Out:
# Pearson, P-Valor =  (0.24717930500379962, 2.6821237348657305e-45)

# %%
width = 12
height = 10
plt.figure(figsize=(width,height))
sns.residplot(df['NDVI_4Q'], df['tch_bloco'])
plt.show()
# Out:
# C:\Users\tiago\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### EDA conclusions
#
# - tch_bloco has a strong positive correlation to NDVI_1Q data, average positive correlation to NDVI_2Q and NDVI_4Q data and a weak correlation to NDVI_3Q data
# - NDVI_1Q is the least distrubuted data from the whole dataset.
# - Variance is rather consistent along all NDVI features. The only exception is the NDVI_3Q, that showed a more spread distribuiton in comparisson to the rest.
#
#
# - When building linear models that demands only one independent variable, it´s reccomended to pick the NDVI_1Q, as it showed the best correlation to the dependent variable (tch_bloco) and a tolerable skewness and variance.

# %% [markdown]
# ## 2. Model building
# For this section, we'll build several different regression models and test their performance (accuracy and MSE wise). In the end, we compare the performance scores from each model against each other to define which one is the best to predict the tch_bloco label
#
# - A. Linear Regression
# - B. Multivariate Linear Regression
# - C. Polynomial Regression
# - D. Support Vector Regression (SVR)
# - E. Deep Neural NEtwork (DNN)

# %% [markdown]
# ### A. Linear Regression

# %%
XLR=df[['NDVI_1Q']].values
yLR=df['tch_bloco']
XLR.shape, yLR.shape
# Out:
# ((3167, 1), (3167,))

# %%
from sklearn.model_selection import train_test_split
X_trainLR, X_testLR, y_trainLR, y_testLR = train_test_split(XLR, yLR, test_size = 0.2, random_state = 0)
X_trainLR.shape, y_testLR.shape, X_testLR.shape, y_trainLR.shape
# Out:
# ((2533, 1), (634,), (634, 1), (2533,))

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_trainLR, y_trainLR)
# Out:
# LinearRegression()

# %%
regressor.intercept_
# Out:
# -23.37498247990338

# %%
regressor.coef_
# Out:
# array([58.03773763])

# %%
accuracy = regressor.score(X_testLR, y_testLR)
print('The R-square is: = ', regressor.score(X_testLR, y_testLR))
# Out:
# The R-square is: =  0.30517070032433957

# %%
from sklearn.metrics import mean_squared_error
yhatLR = regressor.predict(X_testLR)
mseLR = mean_squared_error(y_testLR,yhatLR,squared=False)
print('The Mean squared error of the tch_bloco variable is: ', mseLR)
# Out:
# The Mean squared error of the tch_bloco variable is:  23.7814225321218

# %%
plt.plot(X_testLR,y_testLR, 'ro')
plt.plot(X_testLR, yhatLR)
plt.xlabel('NDVI data (1Quarter)')
plt.ylabel('tch_bloco')
plt.title('Linear Regression')
plt.show()

# %% [markdown]
# ### B. Multivariate Linear Regression

# %%
X_MLR=df[['NDVI_1Q','NDVI_2Q','NDVI_3Q', 'NDVI_4Q']].values
y_MLR=df['tch_bloco']
X_MLR.shape, y_MLR.shape
# Out:
# ((3167, 4), (3167,))

# %%
X_train_MLR, X_test_MLR, y_train_MLR, y_test_MLR = train_test_split(X_MLR, y_MLR, test_size = 0.2, random_state = 0)
X_train_MLR.shape, y_test_MLR.shape, X_test_MLR.shape, y_train_MLR.shape
# Out:
# ((2533, 4), (634,), (634, 4), (2533,))

# %%
MLR=LinearRegression()
MLR.fit(X_train_MLR, y_train_MLR)
# Out:
# LinearRegression()

# %%
MLR.intercept_
# Out:
# -135.25498907504965

# %%
MLR.coef_
# Out:
# array([62.32078531, 22.45709954, 11.45379485, 30.57072623])

# %%
accuracy = MLR.score(X_test_MLR, y_test_MLR)
print('The R-square is: = ', MLR.score(X_test_MLR, y_test_MLR))
# Out:
# The R-square is: =  0.41092738260302897

# %%
yhat_MLR = MLR.predict(X_test_MLR)
mse_MLR = mean_squared_error(y_test_MLR,yhat_MLR,squared=False)
print('The Mean squared error of the tch_bloco variable is: ', mse_MLR)
# Out:
# The Mean squared error of the tch_bloco variable is:  21.8969277362522

# %%
plt.figure(figsize=(width, height))

ax1=sns.distplot(df['tch_bloco'], hist=False, color='r',label='Actual Value')
sns.distplot(yhat_MLR, hist=False, color='b', label='Fitted Values', ax=ax1)

plt.title("Actual vs Fitted Values for tch")
plt.xlabel('tch')
plt.ylabel('Proportion')

plt.show()
plt.close()
# Out:
# C:\Users\tiago\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\tiago\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### C. Polynomial

# %%
def PlotPolly (model, independent_variable, dependent_variable, Name):
    x_new = np.linspace(2.5,0.7,3)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variable, '.', x_new,y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for tch ~ NDVI')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('tch_bloco')

    plt.show()
    plt.close()

# %%
X_Poly=df['NDVI_1Q']
y_Poly=df['tch_bloco']

# %%
f= np.polyfit(X_Poly,y_Poly,5) #5th order polynomial
p = np.poly1d(f)
print(p)
# Out:
#        5        4        3        2
# 138.3 x - 1056 x + 3094 x - 4299 x + 2833 x - 660.7

# %%
PlotPolly(p,X_Poly,y_Poly,'NDVI_1Q')

# %%
np.polyfit(X_Poly,y_Poly,5)
# Out:
# array([  138.26341612, -1055.60437229,  3093.68768532, -4299.09596256,
#         2832.5996978 ,  -660.73235164])

# %%
r_squared = r2_score(y_Poly, p(X_Poly))
print ('The R-square value is: ' , r_squared)

mse_Poly = mean_squared_error(df['tch_bloco'], p(X_Poly))
print ('The Mean squared error of the tch_bloco variable is:', mse_Poly)
# Out:
# The R-square value is:  0.29827477315472894
# The Mean squared error of the tch_bloco variable is: 583.6294896881841

# %% [markdown]
# ### D. Support Vector Regression - SVR

# %%
X_train_SVR = np.array(df[['NDVI_1Q']].values) 
y_train_SVR = np.array(df['tch_bloco'].values) 
y_train_SVR = y_train_SVR.reshape(len(y_train_SVR),1)

# %%
X_test_SVR = np.array(df[['NDVI_1Q']].values) 
y_test_SVR = np.array(df['tch_bloco'].values)
y_test_SVR = y_test_SVR.reshape(len(y_test_SVR),1)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X_train_SVR = sc_X.fit_transform(X_train_SVR)
X_test_SVR = sc_X.fit_transform(X_test_SVR)
y_train_SVR = sc_y.fit_transform(y_train_SVR)
y_test_SVR = sc_y.fit_transform(y_test_SVR)

# %%
from sklearn.svm import SVR
regressor_SVR = SVR(kernel = 'rbf')
regressor_SVR.fit(X_train_SVR, y_train_SVR)
# Out:
# C:\Users\tiago\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# SVR()

# %%
R_squared_SVR = regressor_SVR.score(X_test_SVR, y_test_SVR)
print ('The R-square value is: ' , R_squared_SVR)
# Out:
# The R-square value is:  0.2930000273198822

# %%
yhat_SVR = regressor_SVR.predict(X_test_SVR)
mse_SVR = mean_squared_error(y_test_SVR,yhat_SVR,squared=False)
print('The Mean squared error of the tch_bloco variable is: ', mse_SVR)
# Out:
# The Mean squared error of the tch_bloco variable is:  0.8408329041373903

# %%
plt.scatter(sc_X.inverse_transform(X_test_SVR), sc_y.inverse_transform(y_test_SVR), color = 'red', 
           marker = 'o', s = 35, alpha = 0.5, label = 'Test data')
plt.plot(sc_X.inverse_transform(X_test_SVR), sc_y.inverse_transform(regressor_SVR.predict(X_test_SVR)), 
           color = 'blue', label='Model Plot')
plt.title('Predicted Values vs Inputs')
plt.xlabel('Inputs')
plt.ylabel('Predicted Values')
plt.legend(loc = 'upper left')
plt.show()

# %% [markdown]
# ### E. Deep Neural Network - DNN

# %%
model=tf.keras.models.Sequential()

model.add(tf.keras.layers.Dense(units=8, activation='relu'))
model.add(tf.keras.layers.Dense(units=12, activation='relu'))
model.add(tf.keras.layers.Dense(units=8, activation='relu'))

model.add(tf.keras.layers.Dense(units=1, activation="linear"))

model.compile(
    optimizer=Adam(),
    loss='MSE',
    metrics=[tf.keras.metrics.RootMeanSquaredError()]
    )

M= model.fit(X_train_MLR, y_train_MLR, batch_size=12, epochs = 100, verbose=1, validation_data=(X_test_MLR, y_test_MLR))
# Out:
# Epoch 1/100
# 212/212 [==============================] - 1s 2ms/step - loss: 5589.5811 - root_mean_squared_error: 74.7635 - val_loss: 2789.7305 - val_root_mean_squared_error: 52.8179
# Epoch 2/100
# 212/212 [==============================] - 0s 1ms/step - loss: 1121.5137 - root_mean_squared_error: 33.4890 - val_loss: 707.7909 - val_root_mean_squared_error: 26.6043
# Epoch 3/100
# 212/212 [==============================] - 0s 1ms/step - loss: 723.6401 - root_mean_squared_error: 26.9006 - val_loss: 705.5264 - val_root_mean_squared_error: 26.5617
# Epoch 4/100
# 212/212 [==============================] - 0s 1ms/step - loss: 717.8106 - root_mean_squared_error: 26.7920 - val_loss: 699.2860 - val_root_mean_squared_error: 26.4440
# Epoch 5/100
# 212/212 [==============================] - 0s 1ms/step - loss: 714.3696 - root_mean_squared_error: 26.7277 - val_loss: 691.3337 - val_root_mean_squared_error: 26.2932
# Epoch 6/100
# 212/212 [==============================] - 0s 1ms/step - loss: 709.0584 - root_mean_squared_error: 26.6282 - val_loss: 689.8402 - val_root_mean_squared_error: 26.2648
# Epoch 7/100
# 212/212 [==============================] - 0s 1ms/step - loss: 701.6790 - root_mean_squared_error: 26.4892 - val_loss: 685.7761 - val_root_mean_squared_error: 26.1873
# Epoch 8/100
# 212/212 [==============================] - 0s 1ms/step - loss: 698.6744 - root_mean_squared_error: 26.4325 - val_loss: 678.8313 - val_root_mean_squared_error: 26.0544
# Epoch 9/100
# 212/212 [==============================] - 0s 1ms/step - loss: 692.5658 - root_mean_squared_error: 26.3166 - val_loss: 669.8194 - val_root_mean_squared_error: 25.8809
# Epoch 10/100
# 212/212 [==============================] - 0s 1ms/step - loss: 686.8314 - root_mean_squared_error: 26.2075 - val_loss: 662.6840 - val_root_mean_squared_error: 25.7426
# Epoch 11/100
# 212/212 [==============================] - 0s 1ms/step - loss: 681.1555 - root_mean_squared_error: 26.0990 - val_loss: 661.3545 - val_root_mean_squared_error: 25.7168
# Epoch 12/100
# 212/212 [==============================] - 0s 1ms/step - loss: 677.5142 - root_mean_squared_error: 26.0291 - val_loss: 651.6967 - val_root_mean_squared_error: 25.5284
# Epoch 13/100
# 212/212 [==============================] - 0s 1ms/step - loss: 670.4794 - root_mean_squared_error: 25.8936 - val_loss: 645.8209 - val_root_mean_squared_error: 25.4130
# Epoch 14/100
# 212/212 [==============================] - 0s 1ms/step - loss: 665.4955 - root_mean_squared_error: 25.7972 - val_loss: 641.2333 - val_root_mean_squared_error: 25.3226
# Epoch 15/100
# 212/212 [==============================] - 0s 1ms/step - loss: 659.8007 - root_mean_squared_error: 25.6866 - val_loss: 634.8854 - val_root_mean_squared_error: 25.1969
# Epoch 16/100
# 212/212 [==============================] - 0s 1ms/step - loss: 654.4055 - root_mean_squared_error: 25.5814 - val_loss: 630.3965 - val_root_mean_squared_error: 25.1077
# Epoch 17/100
# 212/212 [==============================] - 0s 1ms/step - loss: 649.4401 - root_mean_squared_error: 25.4841 - val_loss: 624.1083 - val_root_mean_squared_error: 24.9822
# Epoch 18/100
# 212/212 [==============================] - 0s 1ms/step - loss: 645.0601 - root_mean_squared_error: 25.3980 - val_loss: 619.1879 - val_root_mean_squared_error: 24.8835
# Epoch 19/100
# 212/212 [==============================] - 0s 1ms/step - loss: 639.7938 - root_mean_squared_error: 25.2941 - val_loss: 613.3795 - val_root_mean_squared_error: 24.7665
# Epoch 20/100
# 212/212 [==============================] - 0s 1ms/step - loss: 633.7910 - root_mean_squared_error: 25.1752 - val_loss: 609.1547 - val_root_mean_squared_error: 24.6811
# Epoch 21/100
# 212/212 [==============================] - 0s 1ms/step - loss: 631.1456 - root_mean_squared_error: 25.1226 - val_loss: 603.6878 - val_root_mean_squared_error: 24.5701
# Epoch 22/100
# 212/212 [==============================] - 0s 1ms/step - loss: 625.2285 - root_mean_squared_error: 25.0046 - val_loss: 598.2084 - val_root_mean_squared_error: 24.4583
# Epoch 23/100
# 212/212 [==============================] - 0s 1ms/step - loss: 619.3544 - root_mean_squared_error: 24.8868 - val_loss: 593.6982 - val_root_mean_squared_error: 24.3659
# Epoch 24/100
# 212/212 [==============================] - 0s 1ms/step - loss: 614.4747 - root_mean_squared_error: 24.7886 - val_loss: 588.4360 - val_root_mean_squared_error: 24.2577
# Epoch 25/100
# 212/212 [==============================] - 0s 1ms/step - loss: 609.3825 - root_mean_squared_error: 24.6857 - val_loss: 588.8321 - val_root_mean_squared_error: 24.2659
# Epoch 26/100
# 212/212 [==============================] - 0s 1ms/step - loss: 605.9091 - root_mean_squared_error: 24.6152 - val_loss: 579.5475 - val_root_mean_squared_error: 24.0738
# Epoch 27/100
# 212/212 [==============================] - 0s 1ms/step - loss: 601.1558 - root_mean_squared_error: 24.5185 - val_loss: 575.0885 - val_root_mean_squared_error: 23.9810
# Epoch 28/100
# 212/212 [==============================] - 0s 1ms/step - loss: 598.1385 - root_mean_squared_error: 24.4569 - val_loss: 570.6667 - val_root_mean_squared_error: 23.8886
# Epoch 29/100
# 212/212 [==============================] - 0s 1ms/step - loss: 592.1056 - root_mean_squared_error: 24.3332 - val_loss: 566.7217 - val_root_mean_squared_error: 23.8059
# Epoch 30/100
# 212/212 [==============================] - 0s 1ms/step - loss: 588.6868 - root_mean_squared_error: 24.2629 - val_loss: 570.7719 - val_root_mean_squared_error: 23.8908
# Epoch 31/100
# 212/212 [==============================] - 0s 1ms/step - loss: 583.7393 - root_mean_squared_error: 24.1607 - val_loss: 559.8027 - val_root_mean_squared_error: 23.6602
# Epoch 32/100
# 212/212 [==============================] - 0s 1ms/step - loss: 581.0972 - root_mean_squared_error: 24.1060 - val_loss: 554.6499 - val_root_mean_squared_error: 23.5510
# Epoch 33/100
# 212/212 [==============================] - 0s 1ms/step - loss: 577.1016 - root_mean_squared_error: 24.0229 - val_loss: 550.8802 - val_root_mean_squared_error: 23.4708
# Epoch 34/100
# 212/212 [==============================] - 0s 1ms/step - loss: 572.0213 - root_mean_squared_error: 23.9170 - val_loss: 556.8558 - val_root_mean_squared_error: 23.5978
# Epoch 35/100
# 212/212 [==============================] - 0s 1ms/step - loss: 571.3104 - root_mean_squared_error: 23.9021 - val_loss: 545.3263 - val_root_mean_squared_error: 23.3522
# Epoch 36/100
# 212/212 [==============================] - 0s 1ms/step - loss: 565.7020 - root_mean_squared_error: 23.7845 - val_loss: 539.5889 - val_root_mean_squared_error: 23.2291
# Epoch 37/100
# 212/212 [==============================] - 0s 1ms/step - loss: 561.0370 - root_mean_squared_error: 23.6862 - val_loss: 537.3580 - val_root_mean_squared_error: 23.1810
# Epoch 38/100
# 212/212 [==============================] - 0s 1ms/step - loss: 559.5739 - root_mean_squared_error: 23.6553 - val_loss: 533.5224 - val_root_mean_squared_error: 23.0981
# Epoch 39/100
# 212/212 [==============================] - 0s 1ms/step - loss: 555.5692 - root_mean_squared_error: 23.5705 - val_loss: 531.2383 - val_root_mean_squared_error: 23.0486
# Epoch 40/100
# 212/212 [==============================] - 0s 1ms/step - loss: 551.0780 - root_mean_squared_error: 23.4750 - val_loss: 526.3298 - val_root_mean_squared_error: 22.9419
# Epoch 41/100
# 212/212 [==============================] - 0s 1ms/step - loss: 548.3179 - root_mean_squared_error: 23.4162 - val_loss: 524.2155 - val_root_mean_squared_error: 22.8958
# Epoch 42/100
# 212/212 [==============================] - 0s 1ms/step - loss: 543.3909 - root_mean_squared_error: 23.3107 - val_loss: 522.2322 - val_root_mean_squared_error: 22.8524
# Epoch 43/100
# 212/212 [==============================] - 0s 1ms/step - loss: 540.2201 - root_mean_squared_error: 23.2426 - val_loss: 523.2899 - val_root_mean_squared_error: 22.8755
# Epoch 44/100
# 212/212 [==============================] - 0s 1ms/step - loss: 539.2371 - root_mean_squared_error: 23.2215 - val_loss: 515.7038 - val_root_mean_squared_error: 22.7091
# Epoch 45/100
# 212/212 [==============================] - 0s 2ms/step - loss: 534.6838 - root_mean_squared_error: 23.1232 - val_loss: 516.3494 - val_root_mean_squared_error: 22.7233
# Epoch 46/100
# 212/212 [==============================] - 0s 1ms/step - loss: 530.7932 - root_mean_squared_error: 23.0389 - val_loss: 509.7012 - val_root_mean_squared_error: 22.5766
# Epoch 47/100
# 212/212 [==============================] - 0s 1ms/step - loss: 528.0443 - root_mean_squared_error: 22.9792 - val_loss: 508.1979 - val_root_mean_squared_error: 22.5432
# Epoch 48/100
# 212/212 [==============================] - 0s 1ms/step - loss: 525.2190 - root_mean_squared_error: 22.9177 - val_loss: 508.4478 - val_root_mean_squared_error: 22.5488
# Epoch 49/100
# 212/212 [==============================] - 0s 1ms/step - loss: 523.0016 - root_mean_squared_error: 22.8692 - val_loss: 503.1650 - val_root_mean_squared_error: 22.4313
# Epoch 50/100
# 212/212 [==============================] - 0s 1ms/step - loss: 519.7855 - root_mean_squared_error: 22.7988 - val_loss: 501.4716 - val_root_mean_squared_error: 22.3936
# Epoch 51/100
# 212/212 [==============================] - 0s 1ms/step - loss: 513.7817 - root_mean_squared_error: 22.6668 - val_loss: 507.0314 - val_root_mean_squared_error: 22.5174
# Epoch 52/100
# 212/212 [==============================] - 0s 1ms/step - loss: 514.4759 - root_mean_squared_error: 22.6821 - val_loss: 499.1514 - val_root_mean_squared_error: 22.3417
# Epoch 53/100
# 212/212 [==============================] - 0s 1ms/step - loss: 512.2957 - root_mean_squared_error: 22.6340 - val_loss: 498.3847 - val_root_mean_squared_error: 22.3245
# Epoch 54/100
# 212/212 [==============================] - 0s 1ms/step - loss: 510.9369 - root_mean_squared_error: 22.6039 - val_loss: 498.0591 - val_root_mean_squared_error: 22.3172
# Epoch 55/100
# 212/212 [==============================] - 0s 1ms/step - loss: 508.4385 - root_mean_squared_error: 22.5486 - val_loss: 496.2455 - val_root_mean_squared_error: 22.2766
# Epoch 56/100
# 212/212 [==============================] - 0s 1ms/step - loss: 507.8416 - root_mean_squared_error: 22.5353 - val_loss: 495.4536 - val_root_mean_squared_error: 22.2588
# Epoch 57/100
# 212/212 [==============================] - 0s 1ms/step - loss: 504.8996 - root_mean_squared_error: 22.4700 - val_loss: 500.4103 - val_root_mean_squared_error: 22.3699
# Epoch 58/100
# 212/212 [==============================] - 0s 1ms/step - loss: 505.8065 - root_mean_squared_error: 22.4901 - val_loss: 490.1061 - val_root_mean_squared_error: 22.1383
# Epoch 59/100
# 212/212 [==============================] - 0s 1ms/step - loss: 502.8494 - root_mean_squared_error: 22.4243 - val_loss: 488.3163 - val_root_mean_squared_error: 22.0979
# Epoch 60/100
# 212/212 [==============================] - 0s 1ms/step - loss: 500.4845 - root_mean_squared_error: 22.3715 - val_loss: 491.0615 - val_root_mean_squared_error: 22.1599
# Epoch 61/100
# 212/212 [==============================] - 0s 1ms/step - loss: 502.3498 - root_mean_squared_error: 22.4132 - val_loss: 487.3192 - val_root_mean_squared_error: 22.0753
# Epoch 62/100
# 212/212 [==============================] - 0s 1ms/step - loss: 496.7622 - root_mean_squared_error: 22.2882 - val_loss: 487.8216 - val_root_mean_squared_error: 22.0867
# Epoch 63/100
# 212/212 [==============================] - 0s 1ms/step - loss: 496.6864 - root_mean_squared_error: 22.2865 - val_loss: 485.4763 - val_root_mean_squared_error: 22.0335
# Epoch 64/100
# 212/212 [==============================] - 0s 1ms/step - loss: 497.1375 - root_mean_squared_error: 22.2966 - val_loss: 486.0770 - val_root_mean_squared_error: 22.0472
# Epoch 65/100
# 212/212 [==============================] - 0s 1ms/step - loss: 495.4888 - root_mean_squared_error: 22.2596 - val_loss: 488.5089 - val_root_mean_squared_error: 22.1022
# Epoch 66/100
# 212/212 [==============================] - 0s 1ms/step - loss: 496.2194 - root_mean_squared_error: 22.2760 - val_loss: 485.5252 - val_root_mean_squared_error: 22.0346
# Epoch 67/100
# 212/212 [==============================] - 0s 1ms/step - loss: 492.5200 - root_mean_squared_error: 22.1928 - val_loss: 485.2309 - val_root_mean_squared_error: 22.0280
# Epoch 68/100
# 212/212 [==============================] - 0s 1ms/step - loss: 493.1976 - root_mean_squared_error: 22.2081 - val_loss: 485.2114 - val_root_mean_squared_error: 22.0275
# Epoch 69/100
# 212/212 [==============================] - 0s 1ms/step - loss: 493.3593 - root_mean_squared_error: 22.2117 - val_loss: 486.5418 - val_root_mean_squared_error: 22.0577
# Epoch 70/100
# 212/212 [==============================] - 0s 1ms/step - loss: 492.0458 - root_mean_squared_error: 22.1821 - val_loss: 482.7638 - val_root_mean_squared_error: 21.9719
# Epoch 71/100
# 212/212 [==============================] - 0s 1ms/step - loss: 492.2967 - root_mean_squared_error: 22.1878 - val_loss: 483.7858 - val_root_mean_squared_error: 21.9951
# Epoch 72/100
# 212/212 [==============================] - 0s 1ms/step - loss: 494.2982 - root_mean_squared_error: 22.2328 - val_loss: 483.2057 - val_root_mean_squared_error: 21.9819
# Epoch 73/100
# 212/212 [==============================] - 0s 1ms/step - loss: 490.5223 - root_mean_squared_error: 22.1477 - val_loss: 484.5958 - val_root_mean_squared_error: 22.0135
# Epoch 74/100
# 212/212 [==============================] - 0s 1ms/step - loss: 492.0479 - root_mean_squared_error: 22.1822 - val_loss: 482.9931 - val_root_mean_squared_error: 21.9771
# Epoch 75/100
# 212/212 [==============================] - 0s 1ms/step - loss: 490.2122 - root_mean_squared_error: 22.1407 - val_loss: 483.1636 - val_root_mean_squared_error: 21.9810
# Epoch 76/100
# 212/212 [==============================] - 0s 1ms/step - loss: 489.5886 - root_mean_squared_error: 22.1266 - val_loss: 481.9809 - val_root_mean_squared_error: 21.9541
# Epoch 77/100
# 212/212 [==============================] - 0s 1ms/step - loss: 490.8304 - root_mean_squared_error: 22.1547 - val_loss: 481.2928 - val_root_mean_squared_error: 21.9384
# Epoch 78/100
# 212/212 [==============================] - 0s 1ms/step - loss: 488.9688 - root_mean_squared_error: 22.1126 - val_loss: 480.9432 - val_root_mean_squared_error: 21.9304
# Epoch 79/100
# 212/212 [==============================] - 0s 1ms/step - loss: 488.4480 - root_mean_squared_error: 22.1009 - val_loss: 484.4135 - val_root_mean_squared_error: 22.0094
# Epoch 80/100
# 212/212 [==============================] - 0s 1ms/step - loss: 490.5403 - root_mean_squared_error: 22.1481 - val_loss: 482.3492 - val_root_mean_squared_error: 21.9625
# Epoch 81/100
# 212/212 [==============================] - 0s 1ms/step - loss: 488.3418 - root_mean_squared_error: 22.0985 - val_loss: 483.7211 - val_root_mean_squared_error: 21.9937
# Epoch 82/100
# 212/212 [==============================] - 0s 1ms/step - loss: 489.8577 - root_mean_squared_error: 22.1327 - val_loss: 480.6181 - val_root_mean_squared_error: 21.9230
# Epoch 83/100
# 212/212 [==============================] - 0s 1ms/step - loss: 486.9550 - root_mean_squared_error: 22.0671 - val_loss: 480.8788 - val_root_mean_squared_error: 21.9289
# Epoch 84/100
# 212/212 [==============================] - 0s 1ms/step - loss: 489.5442 - root_mean_squared_error: 22.1256 - val_loss: 482.5248 - val_root_mean_squared_error: 21.9664
# Epoch 85/100
# 212/212 [==============================] - 0s 1ms/step - loss: 488.5424 - root_mean_squared_error: 22.1030 - val_loss: 483.9555 - val_root_mean_squared_error: 21.9990
# Epoch 86/100
# 212/212 [==============================] - 0s 1ms/step - loss: 487.1850 - root_mean_squared_error: 22.0723 - val_loss: 480.4684 - val_root_mean_squared_error: 21.9196
# Epoch 87/100
# 212/212 [==============================] - 0s 1ms/step - loss: 486.0289 - root_mean_squared_error: 22.0461 - val_loss: 483.2249 - val_root_mean_squared_error: 21.9824
# Epoch 88/100
# 212/212 [==============================] - 0s 1ms/step - loss: 487.8964 - root_mean_squared_error: 22.0884 - val_loss: 483.4275 - val_root_mean_squared_error: 21.9870
# Epoch 89/100
# 212/212 [==============================] - 0s 1ms/step - loss: 486.4801 - root_mean_squared_error: 22.0563 - val_loss: 479.4946 - val_root_mean_squared_error: 21.8974
# Epoch 90/100
# 212/212 [==============================] - 0s 1ms/step - loss: 486.5705 - root_mean_squared_error: 22.0583 - val_loss: 482.1846 - val_root_mean_squared_error: 21.9587
# Epoch 91/100
# 212/212 [==============================] - 0s 1ms/step - loss: 487.9029 - root_mean_squared_error: 22.0885 - val_loss: 479.4814 - val_root_mean_squared_error: 21.8971
# Epoch 92/100
# 212/212 [==============================] - 0s 1ms/step - loss: 485.7086 - root_mean_squared_error: 22.0388 - val_loss: 482.9277 - val_root_mean_squared_error: 21.9756
# Epoch 93/100
# 212/212 [==============================] - 0s 1ms/step - loss: 487.3677 - root_mean_squared_error: 22.0764 - val_loss: 485.3979 - val_root_mean_squared_error: 22.0317
# Epoch 94/100
# 212/212 [==============================] - 0s 1ms/step - loss: 486.3266 - root_mean_squared_error: 22.0528 - val_loss: 484.7302 - val_root_mean_squared_error: 22.0166
# Epoch 95/100
# 212/212 [==============================] - 0s 1ms/step - loss: 486.7019 - root_mean_squared_error: 22.0613 - val_loss: 481.2981 - val_root_mean_squared_error: 21.9385
# Epoch 96/100
# 212/212 [==============================] - 0s 1ms/step - loss: 486.6943 - root_mean_squared_error: 22.0611 - val_loss: 482.7107 - val_root_mean_squared_error: 21.9707
# Epoch 97/100
# 212/212 [==============================] - 0s 1ms/step - loss: 485.7953 - root_mean_squared_error: 22.0408 - val_loss: 491.3596 - val_root_mean_squared_error: 22.1666
# Epoch 98/100
# 212/212 [==============================] - 0s 1ms/step - loss: 486.3966 - root_mean_squared_error: 22.0544 - val_loss: 480.4356 - val_root_mean_squared_error: 21.9188
# Epoch 99/100
# 212/212 [==============================] - 0s 1ms/step - loss: 486.7072 - root_mean_squared_error: 22.0614 - val_loss: 486.5742 - val_root_mean_squared_error: 22.0584
# Epoch 100/100
# 212/212 [==============================] - 0s 1ms/step - loss: 485.6532 - root_mean_squared_error: 22.0375 - val_loss: 477.6928 - val_root_mean_squared_error: 21.8562

# %%
plt.plot(M.history['loss'], label='loss',color='red')
plt.title(label='Training Loss', weight ='bold')
plt.legend();

# %%
plt.plot(M.history['root_mean_squared_error'], label='root_mean_squared_error',color='blue')
plt.title(label='Training RMSE', weight ='bold')
plt.legend();

# %%
yhat_DNN=model.predict(X_test_MLR, steps=1)
r2_score(y_test_MLR, yhat_DNN)
print('The R-square is: = ', r2_score(y_test_MLR, yhat_DNN))
# Out:
# The R-square is: =  0.4131175184562217

# %%
mse_DNN = mean_squared_error(y_test_MLR,yhat_DNN,squared=False)
print('The Mean squared error of the tch_bloco variable is: ', mse_DNN)
# Out:
# The Mean squared error of the tch_bloco variable is:  21.856184113416056

# %% [markdown]
# ## 3. Models summary

# %% [markdown]
# ### In this section it´s presented the overall performance of each developed model and how they compare against each other

# %%
accuracy_score_model_R2 = {
    'Simple Linear Regression':0.30517070032433957,
    'Multivariate Linear Regression':0.41092738260302897,
    'Polynomial Regression (5th order)':0.29827477315472894,
    'SVR':0.2930000273198822,
    'DNN':0.4131175184562217
}

# %%
def models_overview(accuracy_score_model_R2):
    
    model_accuracy = list(accuracy_score_model_R2.values())
    model_name = list(accuracy_score_model_R2.keys())

    g = sns.barplot(x = model_accuracy, y = model_name,palette='OrRd')
    plt.title('Models Overview', weight='bold');
    return g
    
over_view = models_overview(accuracy_score_model_R2)

# %%
accuracy_score_model_MSE = {
    'Simple Linear Regression':23.7814225321218,
    'Multivariate Linear Regression':21.8969277362522,
    'Polynomial Regression (5th order)':583.6294896881841,
    'SVR':0.8408329041373903,
    'DNN':21.856184113416056
}

# %%
def models_overview(accuracy_score_model_MSE):
    
    model_accuracy = list(accuracy_score_model_MSE.values())
    model_name = list(accuracy_score_model_MSE.keys())

    g = sns.barplot(x = model_accuracy, y = model_name,palette='OrRd')
    plt.title('Models Overview', weight='bold');
    return g
    
over_view = models_overview(accuracy_score_model_MSE)

# %% [markdown]
# ## 4. Conclusions

# %% [markdown]
# ### Based on the performance results, two models can be considered the best alternatives to make 'tch_bloco' label predictions: the Multivariate Linear Regression model (MLR) and the Deep Neural Network.
#
# ### Considering the chosen accuracy metrics (R squared and MSE), both models performed better than other models, displaying the second lowest MSE values (21.89) and the R2 value that is closest to 1 (0.41)
#
# ### However, the DNN takes much more time to run since it uses a series of hidden layers to perform its computation, at the same time that it outputs performance metrics that are are very similar to the MLR model metrics.
#
# ### Therefore, we conclude that the MLR model is the most suitable to predict the tch variable, using all the data from NDVI features (12 variables in total).
